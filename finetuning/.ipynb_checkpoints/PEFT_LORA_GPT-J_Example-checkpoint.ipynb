# %% [markdown]
# # Using 🤗 PEFT & bitsandbytes to finetune a LoRa checkpoint

# %%
# !pip install -q bitsandbytes datasets accelerate loralib -U
#!pip install -q git+https://github.com/huggingface/transformers.git@main git+https://github.com/huggingface/peft.git
# !pip install transformers peft ipywidgets -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in /home/jovyan/.local/lib/python3.8/site-packages (4.31.0)
# Requirement already satisfied: peft in /home/jovyan/.local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: ipywidgets in /home/jovyan/.local/lib/python3.8/site-packages (8.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: safetensors>=0.3.1 in /home/jovyan/.local/lib/python3.8/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.8/site-packages (from transformers) (2022.9.13)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/jovyan/.local/lib/python3.8/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.8/site-packages (from transformers) (1.22.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/jovyan/.local/lib/python3.8/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.8/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: accelerate in /home/jovyan/.local/lib/python3.8/site-packages (from peft) (0.21.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.8/site-packages (from peft) (5.9.2)
# Requirement already satisfied: torch>=1.13.0 in /home/jovyan/.local/lib/python3.8/site-packages (from peft) (2.0.1)
# Requirement already satisfied: comm>=0.1.3 in /home/jovyan/.local/lib/python3.8/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/jovyan/.local/lib/python3.8/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/jovyan/.local/lib/python3.8/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.8/site-packages (from ipywidgets) (8.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.8/site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2022.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.4.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.5.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (2.14.3)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.7.4.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.4.0.1)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (10.2.10.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (10.9.0.58)
# Requirement already satisfied: sympy in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (8.5.0.96)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.7.91)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.8/site-packages (from torch>=1.13.0->peft) (2.6.3)
# Requirement already satisfied: triton==2.0.0 in /home/jovyan/.local/lib/python3.8/site-packages (from torch>=1.13.0->peft) (2.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->peft) (59.5.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->peft) (0.37.1)
# Requirement already satisfied: cmake in /home/jovyan/.local/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.13.0->peft) (3.27.0)
# Requirement already satisfied: lit in /home/jovyan/.local/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.13.0->peft) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.8/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: asttokens in /opt/conda/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.8)
# Requirement already satisfied: executing in /opt/conda/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /home/jovyan/.local/lib/python3.8/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)

# %%
# Does work
import sys
sys.path.append('/home/jovyan/.local/bin')
sys.path.append('/home/jovyan/.local/lib/python3.8/site-packages')
import sys
display(sys.path)
# Out:
# ['/workspace/pv-data/InternFolders/zenchang/FalconAI/Web_App/models',
#  '/home/jovyan/.conda/envs/gpt/lib/python311.zip',
#  '/home/jovyan/.conda/envs/gpt/lib/python3.11',
#  '/home/jovyan/.conda/envs/gpt/lib/python3.11/lib-dynload',
#  '',
#  '/home/jovyan/.conda/envs/gpt/lib/python3.11/site-packages',
#  '/home/jovyan/.local/bin',
#  '/home/jovyan/.local/lib/python3.8/site-packages']

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-2e627182-d6e4-5bd2-0ce8-3e5611885128)

# %% [markdown]
# ### Setup the model

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import torch
import torch.nn as nn
import bitsandbytes as bnb
from transformers import AutoTokenizer, AutoConfig, AutoModelForCausalLM, GPTJForCausalLM

# model = AutoModelForCausalLM.from_pretrained(
#     "bigscience/bloom-7b1",
#     load_in_8bit=True,
#     device_map='auto',
# )

#tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-7b1")

model_name = 'EleutherAI/gpt-j-6B'
model = GPTJForCausalLM.from_pretrained(
    model_name,
    load_in_8bit=True,
    device_map='auto',
)

# %%
# Get tokenizer stuff
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.save_pretrained("./models/tokenizer/")
# Out:
# ('./models/tokenizer/tokenizer_config.json',
#  './models/tokenizer/special_tokens_map.json',
#  './models/tokenizer/vocab.json',
#  './models/tokenizer/merges.txt',
#  './models/tokenizer/added_tokens.json',
#  './models/tokenizer/tokenizer.json')

# %% [markdown]
# ### Freezing the original weights

# %%
for param in model.parameters():
  param.requires_grad = False  # freeze the model - train adapters later
  if param.ndim == 1:
    # cast the small parameters (e.g. layernorm) to fp32 for stability
    param.data = param.data.to(torch.float32)

model.gradient_checkpointing_enable()  # reduce number of stored activations
model.enable_input_require_grads()

class CastOutputToFloat(nn.Sequential):
  def forward(self, x): return super().forward(x).to(torch.float32)
model.lm_head = CastOutputToFloat(model.lm_head)

# %% [markdown]
# ### Setting up the LoRa Adapters

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=16, #attention heads
    lora_alpha=32, #alpha scaling
    # target_modules=["q_proj", "v_proj"], #if you know the
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM" # set this for CLM or Seq2Seq
)

model = get_peft_model(model, config)
print_trainable_parameters(model)
# Out:
# trainable params: 7340032 || all params: 6058222816 || trainable%: 0.12115817167725645

# %% [markdown]
# ## Data

# %%
import transformers
from datasets import load_dataset

# data = load_dataset("Abirate/english_quotes")

data = load_dataset("text", data_files={"train": "train.txt", "validation": "test.txt"})
display (data)
display(data['train'][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 51576
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 12894
#     })
# })
# {'text': '<BOS> 2.82  RADAR HANDBOOK 6x9 Handbook  / Radar Handbook / Skolnik / 148547-3 / Chapter 2 When doppler shifts are introduced by digital means as described above, the accu - racy of the I and Q representation of the original input data becomes an important  consideration. Any dc offset, amplitude imbalance, quadrature phase error, or nonlin - earity will result in the generation of undesired sidebands that will appear as residue  at the canceler output. A discussion of A/D conversion considerations was presented  in Section 2.13. <EOS>'}

# %%
def merge_columns(example):
    example["prediction"] = example["quote"] + " ->: " + str(example["tags"])
    return example

# data['train'] = data['train'].map(merge_columns)
# display(data['train'])

display(data['train'])
display(data['train']["text"][:5])
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 51576
# })
# ['<BOS> 2.82  RADAR HANDBOOK 6x9 Handbook  / Radar Handbook / Skolnik / 148547-3 / Chapter 2 When doppler shifts are introduced by digital means as described above, the accu - racy of the I and Q representation of the original input data becomes an important  consideration. Any dc offset, amplitude imbalance, quadrature phase error, or nonlin - earity will result in the generation of undesired sidebands that will appear as residue  at the canceler output. A discussion of A/D conversion considerations was presented  in Section 2.13. <EOS>',
#  '<BOS> This time delay, which istheobserved quantity, may then beregarded asameasure ofthe rate ofchange ofphase with frequency ofthereturned components. 5.4. Class ofSystems Considered.—In this chapter wewill consider that class ofsystems inwhich the modulation issuch that energy is emitted all, ornearly all,the time. <EOS>',
#  '<BOS> \x17\x16\x11 \x00 0HYS\x0e\x003CI\x0e\x002ES\x0e \x000APER\x00\x12\x19\x10 \x00\x11\x19\x16\x16\x0e \x11\x16\x0e\x00+\x0e\x003\x0e\x00+ELLEHER\x00AND\x00(\x0e\x000\x0e\x00#OLEMAN \x00h/FF <EOS>',
#  '<BOS> Thelossesindecibels per100ftforradar transmission linesareshowninFig.2.28.Atthelowerradarfrequencies thetransmission line introduces littleloss,unlessitslengthisexceptionally long.Atthehigherradarfrequencies, attenuation maynotalwaysbesmallandmayhavetobetakenintoaccount. Inaddition tothe losscsinthetransmission lincitself,anadditional losscanoccurateachconnection orbendin thelineandattheantenna rotaryjointifused.Connector lossesareusuallysmall,butifthe connection ispoorlymade,itcancontribute significant attenuation. Sincethesametransmis\xad sionlineisgenerally usedforbothreceiving andtransmission, thelosstobeinserted inthe radarequation istwicetheone-way loss. <EOS>',
#  "<BOS> Another important consideration'in the selection of an antenna element and the design of  an array, is the mutual coupling between the radiating elements. When the field intensity  pattern of an array antenna was .considered previously [Eq. (8.3)) it was assumed that the  elemental radiators were independent of one another. <EOS>"]

# %%
data['train'][0]
# Out:
# {'text': '<BOS> 2.82  RADAR HANDBOOK 6x9 Handbook  / Radar Handbook / Skolnik / 148547-3 / Chapter 2 When doppler shifts are introduced by digital means as described above, the accu - racy of the I and Q representation of the original input data becomes an important  consideration. Any dc offset, amplitude imbalance, quadrature phase error, or nonlin - earity will result in the generation of undesired sidebands that will appear as residue  at the canceler output. A discussion of A/D conversion considerations was presented  in Section 2.13. <EOS>'}

# %%
#data = data.map(lambda samples: tokenizer(samples['prediction']), batched=True)
##data = data.map(lambda samples: tokenizer(samples), batched=True)

data = data.map(lambda samples: tokenizer(samples['text']), batched=True)

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'input_ids', 'attention_mask'],
#         num_rows: 51576
#     })
#     validation: Dataset({
#         features: ['text', 'input_ids', 'attention_mask'],
#         num_rows: 12894
#     })
# })

# %% [markdown]
# ### Training

# %%
tokenizer.pad_token = tokenizer.eos_token

trainer = transformers.Trainer(
    model=model,
    train_dataset=data['train'],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=100,
#         max_steps=200,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir='outputs'
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = True # silence the warnings. Please re-enable for inference!
trainer.train()
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /home/jovyan/.conda/envs/gpt/lib/python3.11/site-packages/bitsandbytes/autograd/_functions.py:322: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#     <div>
#
#       <progress value='746' max='9669' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 746/9669 38:12 < 7:38:20, 0.32 it/s, Epoch 0.23/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.354400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.296200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.834300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.967300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.327900</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.369100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.470600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.976800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.488200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.853100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.784500</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.403900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>3.852900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.811700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.912200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.735200</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>4.130600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.602200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.527800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.463800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.560500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.520100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>3.417800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.979200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>3.969500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>3.743900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>3.925700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>3.163200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.826700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>3.360600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>3.479700</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>3.265900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>3.472100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.457700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>3.522900</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>3.239100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>3.345500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>3.514900</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>3.103000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.901500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.927200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>3.107500</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.843300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>3.332300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>3.129000</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>3.176100</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.778000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.184100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.810600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.936500</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>2.918500</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>2.918100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.729600</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.828500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.814000</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>3.197200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>3.344000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>3.077600</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>3.260200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>3.034900</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>3.019700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>3.141900</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>3.430100</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>2.513500</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.987300</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>2.904000</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>2.953600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>2.719200</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>2.889000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.941800</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>2.967300</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>2.674800</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>2.940400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>3.274600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>3.388800</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.730300</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.807300</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>2.922100</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>3.052000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.780600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>2.866800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>2.762900</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>3.140700</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>3.144300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>3.148900</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.800500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>2.951300</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>2.601700</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>2.798500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.644700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>2.403300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>2.859500</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>3.038100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>2.729100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.832300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.773200</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>2.716800</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>2.353600</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>2.677900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.702700</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>2.813700</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>3.090400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.499400</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.746400</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>2.813600</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>3.111000</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.786300</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>2.752700</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>2.736200</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.386000</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.877400</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.801300</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>2.842700</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.551600</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.958300</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>2.311800</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>2.597300</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>3.049800</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>2.824000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.939400</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>3.283700</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>2.933300</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>2.711600</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>2.897100</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>2.659600</td>
#     </tr
# /home/jovyan/.conda/envs/gpt/lib/python3.11/site-packages/bitsandbytes/autograd/_functions.py:322: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [0,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [1,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [2,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [3,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [4,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [5,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [6,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [7,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [8,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [9,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [10,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [11,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [12,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [13,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [14,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [15,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [16,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [17,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [18,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [19,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [20,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [21,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [22,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [23,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [24,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [25,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [26,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [27,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [28,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [29,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [30,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [300,0,0], thread: [31,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [96,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [97,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [98,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [99,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [100,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [101,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [102,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [103,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [104,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [105,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [106,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [107,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [108,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [109,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [110,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [111,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [112,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [113,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [114,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [115,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [116,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [117,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [118,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [119,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [120,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [121,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [122,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [123,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [124,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [125,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [126,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [127,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [96,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [97,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [98,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [99,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [100,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [101,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [102,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [103,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [104,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [105,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [106,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [107,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [108,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [109,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [110,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [111,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [112,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [113,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [114,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [115,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [116,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [117,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [118,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [119,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [120,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [121,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [122,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [123,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [124,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [125,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [126,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [127,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [0,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [1,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [2,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [3,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [4,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [5,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [6,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [7,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [8,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [9,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [10,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [11,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [12,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [13,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [14,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [15,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [16,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [17,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [18,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [19,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [20,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [21,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [22,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [23,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [24,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [25,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [26,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [27,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [28,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [29,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [30,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [31,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [32,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [33,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [34,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [35,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [36,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [37,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [38,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [39,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [40,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [41,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [42,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [43,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [44,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [45,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [46,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [47,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [48,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [49,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [50,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [51,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [52,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [53,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [54,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [55,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [56,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [57,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [58,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [59,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [60,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [61,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [62,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [63,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [64,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [65,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [66,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [67,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [68,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [69,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [70,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [71,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [72,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [73,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [74,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [75,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [76,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [77,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [78,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [79,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [80,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [81,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [82,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [83,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [84,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [85,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [86,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [87,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [88,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [89,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [90,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [91,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [92,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [93,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [94,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [279,0,0], thread: [95,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [0,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [1,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [2,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [3,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [4,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [5,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [6,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [7,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [8,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [9,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [10,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [11,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [12,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [13,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [14,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [15,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [16,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [17,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/ScatterGatherKernel.cu:144: operator(): block: [332,0,0], thread: [18,0,0] Assertion `idx_dim >= 0 && idx_dim < index_size && "index out of bounds"` failed.
# ...
#       3 trainer = transformers.Trainer(
#       4     model=model,
#       5     train_dataset=data['train'],
#    (...)
#      16     data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
#      17 )
#      18 model.config.use_cache = True # silence the warnings. Please re-enable for inference!
# ---> 19 trainer.train()
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/trainer.py:1534, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1529     self.model_wrapped = self.model
#    1531 inner_training_loop = find_executable_batch_size(
#    1532     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1533 )
# -> 1534 return inner_training_loop(
#    1535     args=args,
#    1536     resume_from_checkpoint=resume_from_checkpoint,
#    1537     trial=trial,
#    1538     ignore_keys_for_eval=ignore_keys_for_eval,
#    1539 )
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/trainer.py:1807, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1804     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1806 with self.accelerator.accumulate(model):
# -> 1807     tr_loss_step = self.training_step(model, inputs)
#    1809 if (
#    1810     args.logging_nan_inf_filter
#    1811     and not is_torch_tpu_available()
#    1812     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1813 ):
#    1814     # if loss is nan or inf simply add the average of previous logged losses
#    1815     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/trainer.py:2649, in Trainer.training_step(self, model, inputs)
#    2646     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2648 with self.compute_loss_context_manager():
# -> 2649     loss = self.compute_loss(model, inputs)
#    2651 if self.args.n_gpu > 1:
#    2652     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/trainer.py:2674, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2672 else:
#    2673     labels = None
# -> 2674 outputs = model(**inputs)
#    2675 # Save past state if it exists
#    2676 # TODO: this needs to be fixed and made cleaner later.
#    2677 if self.args.past_index >= 0:
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/utils/operations.py:632, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     631 def forward(*args, **kwargs):
# --> 632     return model_forward(*args, **kwargs)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/utils/operations.py:620, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     619 def __call__(self, *args, **kwargs):
# --> 620     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/amp/autocast_mode.py:14, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      11 @functools.wraps(func)
#      12 def decorate_autocast(*args, **kwargs):
#      13     with autocast_instance:
# ---> 14         return func(*args, **kwargs)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/utils/operations.py:632, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     631 def forward(*args, **kwargs):
# --> 632     return model_forward(*args, **kwargs)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/utils/operations.py:620, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     619 def __call__(self, *args, **kwargs):
# --> 620     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/amp/autocast_mode.py:14, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      11 @functools.wraps(func)
#      12 def decorate_autocast(*args, **kwargs):
#      13     with autocast_instance:
# ---> 14         return func(*args, **kwargs)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/peft/peft_model.py:948, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#     937             raise AssertionError("forward in MPTForCausalLM does not support inputs_embeds")
#     938         return self.base_model(
#     939             input_ids=input_ids,
#     940             attention_mask=attention_mask,
#    (...)
#     945             **kwargs,
#     946         )
# --> 948     return self.base_model(
#     949         input_ids=input_ids,
#     950         attention_mask=attention_mask,
#     951         inputs_embeds=inputs_embeds,
#     952         labels=labels,
#     953         output_attentions=output_attentions,
#     954         output_hidden_states=output_hidden_states,
#     955         return_dict=return_dict,
#     956         **kwargs,
#     957     )
#     959 batch_size = _get_batch_size(input_ids, inputs_embeds)
#     960 if attention_mask is not None:
#     961     # concat prompt attention mask
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(*args, **kwargs)
#     163         output = old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/models/gptj/modeling_gptj.py:854, in GPTJForCausalLM.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     846 r"""
#     847 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#     848     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#     849     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#     850     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#     851 """
#     852 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 854 transformer_outputs = self.transformer(
#     855     input_ids,
#     856     past_key_values=past_key_values,
#     857     attention_mask=attention_mask,
#     858     token_type_ids=token_type_ids,
#     859     position_ids=position_ids,
#     860     head_mask=head_mask,
#     861     inputs_embeds=inputs_embeds,
#     862     use_cache=use_cache,
#     863     output_attentions=output_attentions,
#     864     output_hidden_states=output_hidden_states,
#     865     return_dict=return_dict,
#     866 )
#     867 hidden_states = transformer_outputs[0]
#     869 # Set device for model parallelism
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(*args, **kwargs)
#     163         output = old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/models/gptj/modeling_gptj.py:680, in GPTJModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     676             return module(*inputs, use_cache, output_attentions)
#     678         return custom_forward
# --> 680     outputs = torch.utils.checkpoint.checkpoint(
#     681         create_custom_forward(block),
#     682         hidden_states,
#     683         None,
#     684         attention_mask,
#     685         position_ids,
#     686         head_mask[i],
#     687     )
#     688 else:
#     689     outputs = block(
#     690         hidden_states=hidden_states,
#     691         layer_past=layer_past,
#    (...)
#     696         output_attentions=output_attentions,
#     697     )
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/utils/checkpoint.py:249, in checkpoint(function, use_reentrant, *args, **kwargs)
#     246     raise ValueError("Unexpected keyword arguments: " + ",".join(arg for arg in kwargs))
#     248 if use_reentrant:
# --> 249     return CheckpointFunction.apply(function, preserve, *args)
#     250 else:
#     251     return _checkpoint_without_reentrant(
#     252         function,
#     253         preserve,
#     254         *args,
#     255         **kwargs,
#     256     )
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/autograd/function.py:506, in Function.apply(cls, *args, **kwargs)
#     503 if not torch._C._are_functorch_transforms_active():
#     504     # See NOTE: [functorch vjp and autograd interaction]
#     505     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     508 if cls.setup_context == _SingleLevelFunction.setup_context:
#     509     raise RuntimeError(
#     510         'In order to use an autograd.Function with functorch transforms '
#     511         '(vmap, grad, jvp, jacrev, ...), it must override the setup_context '
#     512         'staticmethod. For more details, please see '
#     513         'https://pytorch.org/docs/master/notes/extending.func.html')
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/utils/checkpoint.py:107, in CheckpointFunction.forward(ctx, run_function, preserve_rng_state, *args)
#     104 ctx.save_for_backward(*tensor_inputs)
#     106 with torch.no_grad():
# --> 107     outputs = run_function(*args)
#     108 return outputs
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/models/gptj/modeling_gptj.py:676, in GPTJModel.forward.<locals>.create_custom_forward.<locals>.custom_forward(*inputs)
#     674 def custom_forward(*inputs):
#     675     # None for past_key_value
# --> 676     return module(*inputs, use_cache, output_attentions)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(*args, **kwargs)
#     163         output = old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/models/gptj/modeling_gptj.py:309, in GPTJBlock.forward(self, hidden_states, layer_past, attention_mask, position_ids, head_mask, use_cache, output_attentions)
#     307 residual = hidden_states
#     308 hidden_states = self.ln_1(hidden_states)
# --> 309 attn_outputs = self.attn(
#     310     hidden_states=hidden_states,
#     311     layer_past=layer_past,
#     312     attention_mask=attention_mask,
#     313     position_ids=position_ids,
#     314     head_mask=head_mask,
#     315     use_cache=use_cache,
#     316     output_attentions=output_attentions,
#     317 )
#     318 attn_output = attn_outputs[0]  # output_attn: a, present, (attentions)
#     319 outputs = attn_outputs[1:]
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(*args, **kwargs)
#     163         output = old_forward(*args, **kwargs)
#     164 else:
# --> 165     output = old_forward(*args, **kwargs)
#     166 return module._hf_hook.post_forward(module, output)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/models/gptj/modeling_gptj.py:233, in GPTJAttention.forward(self, hidden_states, layer_past, attention_mask, position_ids, head_mask, use_cache, output_attentions)
#     230 q_rot = query[:, :, :, : self.rotary_dim]
#     231 q_pass = query[:, :, :, self.rotary_dim :]
# --> 233 k_rot = apply_rotary_pos_emb(k_rot, sin, cos)
#     234 q_rot = apply_rotary_pos_emb(q_rot, sin, cos)
#     236 key = torch.cat([k_rot, k_pass], dim=-1)
#
# File ~/.conda/envs/gpt/lib/python3.11/site-packages/transformers/models/gptj/modeling_gptj.py:77, in apply_rotary_pos_emb(tensor, sin, cos)
#      76 def apply_rotary_pos_emb(tensor: torch.Tensor, sin: torch.Tensor, cos: torch.Tensor) -> torch.Tensor:
# ---> 77     sin = torch.repeat_interleave(sin[:, :, None, :], 2, 3)
#      78     cos = torch.repeat_interleave(cos[:, :, None, :], 2, 3)
#      79     return (tensor * cos) + (rotate_every_two(tensor) * sin)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# Save model to disk
trainer.save_model()

# %% [markdown]
# ## Share adapters on the 🤗 Hub

# %%
# Get write token from huggingface
! python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"

# %%
# fine_tuned_model = GPTJForCausalLM.from_pretrained("./distilgptj-finetuned-radar")
model.push_to_hub("Fiery101/distilgptj-finetuned-radar", create_pr=1)
tokenizer.push_to_hub("Fiery101/distilgptj-finetuned-radar")
# model.push_to_hub("samwit/bloom-7b1-lora-tagger",
#                   use_auth_token=True,
#                   commit_message="basic training",
#                   private=True)

# %% [markdown]
# ## Load adapters from the Hub

# %%
# import torch
# from peft import PeftModel, PeftConfig
# from transformers import AutoModelForCausalLM, AutoTokenizer

# peft_model_id = "Fiery101/distilgptj-finetuned-radar"
# config = PeftConfig.from_pretrained(peft_model_id)
# model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, return_dict=True, load_in_8bit=True, device_map='auto')
# tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# # Load the Lora model
# model = PeftModel.from_pretrained(model, peft_model_id)

# %% [markdown]
# ## Inference

# %%
batch = tokenizer("“Training models with PEFT and LoRa is cool” ->: ", return_tensors='pt')

with torch.cuda.amp.autocast():
  output_tokens = model.generate(**batch, max_new_tokens=50)

print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True))
